# %%
from bs4 import BeautifulSoup
import logging
import numpy as np
import pandas as pd
import requests
from tqdm import tqdm

# %%
link_template = 'https://dblp.org/db/conf/sigir/sigir2024.html'
def get_title_author(link):
    resp = requests.get(link, proxies=None)
    soup = BeautifulSoup(resp.content, 'html.parser')
    uls = soup.find_all('ul', class_='publ-list')
    titles, authors = [], []
    for ul in uls[2:]:  # 遍历所有 ul
        articles = ul.find_all('li', class_='entry inproceedings')  # 找到当前 ul 下的所有 li
        print(f"Found {len(articles)} articles in one ul.")
        for li in articles:
            title = li.find('span', class_='title').text
            author_list = [a.text for a in li.find_all('span', itemprop='name')]

            titles.append(title)
            authors.append(", ".join(author_list[:-1]))

    return titles, authors

# %%
titles, authors = get_title_author(link_template)
print(titles, authors)
# Out:
# Found 5 articles in one ul.
# Found 8 articles in one ul.
# Found 5 articles in one ul.
# Found 5 articles in one ul.
# Found 7 articles in one ul.
# Found 7 articles in one ul.
# Found 6 articles in one ul.
# Found 3 articles in one ul.
# Found 3 articles in one ul.
# Found 5 articles in one ul.
# Found 3 articles in one ul.
# Found 6 articles in one ul.
# Found 5 articles in one ul.
# Found 5 articles in one ul.
# Found 7 articles in one ul.
# Found 5 articles in one ul.
# Found 2 articles in one ul.
# Found 7 articles in one ul.
# Found 4 articles in one ul.
# Found 3 articles in one ul.
# Found 11 articles in one ul.
# Found 6 articles in one ul.
# Found 6 articles in one ul.
# Found 4 articles in one ul.
# Found 4 articles in one ul.
# Found 5 articles in one ul.
# Found 5 articles in one ul.
# Found 6 articles in one ul.
# Found 7 articles in one ul.
# Found 7 articles in one ul.
# Found 7 articles in one ul.
# Found 4 articles in one ul.
# Found 3 articles in one ul.
# Found 5 articles in one ul.
# Found 6 articles in one ul.
# Found 9 articles in one ul.
# Found 7 articles in one ul.
# Found 5 articles in one ul.
# Found 6 articles in one ul.
# Found 87 articles in one ul.
# Found 23 articles in one ul.
# Found 5 articles in one ul.
# Found 4 articles in one ul.
# Found 6 articles in one ul.
# Found 3 articles in one ul.
# Found 6 articles in one ul.
# Found 4 articles in one ul.
# Found 3 articles in one ul.
# Found 1 articles in one ul.
# Found 10 articles in one ul.
# Found 13 articles in one ul.
# Found 9 articles in one ul.
# ['TRAD: Enhancing LLM Agents with Step-Wise Thought Retrieval and Aligned Decision.', '"In-Context Learning" or: How I learned to stop worrying and love "Applied Information Retrieval".', 'CorpusLM: Towards a Unified Language Model on Corpus for Knowledge-Intensive Tasks.', 'A Setwise Approach for Effective and Highly Efficient Zero-shot Ranking with Large Language Models.', 'Unsupervised Large Language Model Alignment for Information Retrieval via Contrastive Feedback.', 'MetaHKG: Meta Hyperbolic Learning for Few-shot Temporal Reasoning.', 'Transformer-based Reasoning for Learning Evolutionary Chain of Events on Temporal Knowledge Graph.', 'LDRE: LLM-based Divergent Reasoning and Ensemble for Zero-Shot Composed Image Retrieval.', 'NativE: Multi-modal Knowledge Graph Completion in the Wild.', 'Contrast then Memorize: Semantic Neighbor Retrieval-Enhanced Inductive Multimodal Knowledge Graph Completion.', 'EditKG: Editing Knowledge Graph for Recommendation.', 'Amazon-KG: A Knowledge Graph Enhanced Cross-Domain Recommendation Dataset.', 'YAGO 4.5: A Large and Clean Knowledge Base with a Rich Taxonomy.', 'Ranked List Truncation for Large Language Model-based Re-Ranking.', 'Efficient Inverted Indexes for Approximate Retrieval over Learned Sparse Representations.', 'GUITAR: Gradient Pruning toward Fast Neural Ranking.', 'Neural Passage Quality Estimation for Static Pruning.', 'Revisiting Document Expansion and Filtering for Effective First-Stage Retrieval.', 'Unsupervised Cross-Domain Image Retrieval with Semantic-Attended Mixture-of-Experts.', 'Invisible Relevance Bias: Text-Image Retrieval Models Prefer AI-Generated Images.', 'COMI: COrrect and MItigate Shortcut Learning Behavior in Deep Neural Networks.', 'Simple but Effective Raw-Data Level Multimodal Fusion for Composed Image Retrieval.', 'Fine-grained Textual Inversion Network for Zero-Shot Composed Image Retrieval.', 'The Treatment of Ties in Rank-Biased Overlap.', 'Uncontextualized significance considered dangerous.', 'Can We Trust Recommender System Fairness Evaluation? The Role of Fairness and Relevance.', 'What Matters in a Measure? A Perspective from Large-Scale Search Evaluation.', 'CIRAL: A Test Collection for CLIR Evaluations in African Languages.', 'ACORDAR 2.0: A Test Collection for Ad Hoc Dataset Retrieval with Densely Pooled Datasets and Question-Style Queries.', 'Browsing and Searching Metadata of TREC.', 'Large Language Models for Intent-Driven Session Recommendations.', 'Sequential Recommendation with Latent Relations based on Large Language Model.', 'Enhancing Sequential Recommenders with Augmented Knowledge from Aligned Large Language Models.', 'IDGenRec: LLM-RecSys Alignment with Textual ID Learning.', 'Data-efficient Fine-tuning for LLM-based Recommendation.', 'Reinforcement Learning-based Recommender Systems with Large Language Models for State Reward and Action Modeling.', 'OpenP5: An Open-Source Platform for Developing, Training, and Evaluating LLM-based Recommender Systems.', 'Fair Sequential Recommendation without User Demographics.', 'CaDRec: Contextualized and Debiased Recommender Model.', 'Going Beyond Popularity and Positivity Bias: Correcting for Multifactorial Bias in Recommender Systems.', 'Adaptive Fair Representation Learning for Personalized Fairness in Recommendations via Information Alignment.', 'Configurable Fairness for New Item Recommendation Considering Entry Time of Items.', 'Fair Recommendations with Limited Sensitive Attributes: A Distributionally Robust Optimization Approach.', 'Generative Retrieval via Term Set Generation.', 'Planning Ahead in Generative Retrieval: Guiding Autoregressive Generation through Simultaneous Decoding.', 'Large Language Models and Future of Information Retrieval: Opportunities and Challenges.', 'GraphGPT: Graph Instruction Tuning for Large Language Models.', 'Instruction-based Hypergraph Pretraining.', 'LLM-enhanced Cascaded Multi-level Learning on Temporal Heterogeneous Graphs.', 'Course Recommender Syst ...

# %%
print(len(titles), len(authors))
# Out:
# 388 388

# %%
def graph_mask(title):
    t = title.lower()
    conditions = ['graph neural networks', 'gnns', 'gnn', 'graph', 'graph learning', 'graph embedding', 'network embedding']
    return np.any([c in t for c in conditions])

# %%
with open(f'2024-SIGIR.txt', 'w', encoding='utf8') as fw:
    for t, n in zip(titles, authors):
        if graph_mask(t):
            fw.write(f'1. **{t}**\n\n')
            fw.write(f'    *{n}*\n\n')
