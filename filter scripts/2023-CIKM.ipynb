# %%
from bs4 import BeautifulSoup
import logging
import numpy as np
import pandas as pd
import requests
from tqdm import tqdm

# %%
link_template = 'https://cikm2024.org/accepted-papers/'
def get_title_author(link):
    resp = requests.get(link, proxies=None)
    soup = BeautifulSoup(resp.content, 'html.parser')
    articles = soup.find('table', class_='dataframe')
    titles, authors = [], []
    articles = articles.find_all('tr')[1:]
    for art in tqdm(articles):
        title = art.find_all('td')[1].get_text(strip=True)
        author = art.find_all('td')[2].get_text(strip=True)
        titles.append(title)
        authors.append(author)
    return titles, authors

# %%
titles, authors = get_title_author(link_template)
print(titles, authors)
# Out:
# 100%|██████████| 348/348 [00:00<00:00, 14667.02it/s]
# ['Let Silence Speak: Enhancing Fake News Detection with Generated Comments from Large Language Models', 'Distilling Multi-Scale Knowledge for Event Temporal Relation Extraction', 'PRISM: Mitigating EHR Data Sparsity via Learning from Missing Feature Calibrated Prototype Patient Representations', 'Post-Quantum Searchable Encryption Supporting User-Authorization for Outsourced Data Management', 'Novelty-aware Graph Traversal and Expansion for Hierarchical Reinforcement Learning', 'Progressive Multimodal Pivot Learning: Towards Semantic Discordance Understanding as Humans', 'Mining Path Association Rules in Large Property Graphs', 'CKNN: Cleansed k-Nearest Neighbor for Unsupervised Video Anomaly Detection', 'LTBoost: Boosted Hybrids of Ensemble Linear and Gradient Algorithms for the Long-term Time Series Forecasting', 'What a Surprise! Computing Rewritten Modules Can Be as Efficient as Computing Subset Modules', 'Natural Language-Assisted Multi-modal Medication Recommendation', 'Accurate Neural Network Option Pricing Methods with Control Variate Techniques and Data Synthesis/Cleaning with Financial Rationality', 'Practical and Robust Safety Guarantees for Advanced Counterfactual Learning to Rank', 'MTSCI: A Conditional Diffusion Model for Multivariate Time Series Consistent Imputation', 'Sparks of Surprise: Multi-objective Recommendations with Hierarchical Decision Transformers for Diversity, Novelty, and Serendipity', 'Aligning Query Representation with Rewritten Query and Relevance Judgments in Conversational Search', 'Collaborative Alignment for Recommendation', 'Interpretable Triplet Importance for Personalized Ranking', 'Adaptive Differentially Private Structural Entropy Minimization for Unsupervised Social Event Detection', 'HiLite: Hierarchical Level-implemented Architecture Attaining Part-Whole Interpretability', 'Discrepancy-guided Channel Dropout for Domain Generalization', 'PSNE: Efficient Spectral Sparsification Algorithms for Scaling Network Embedding', 'A Geometric Perspective for High-Dimensional Multiplex Graphs', 'CausalMed: Causality-Based Personalized Medication Recommendation Centered on Patient Health State', 'Table-Filling via Mean Teacher for Cross-domain Aspect Sentiment Triplet Extraction', 'Explainable Stock Price Movement Prediction using Contrastive Learning', 'Reviving the Context: Camera Trap Species Classification as Link Prediction on Multimodal Knowledge Graphs', 'Predicting Scientific Impact Through Diffusion, Conformity, and Contribution Disentanglement', 'Hierarchical Graph Latent Diffusion Model for Conditional Molecule Generation', 'A Learning-based Approach for Explaining Language Models', 'MultiLoRA: Multi-Directional Low Rank Adaptation for Multi-Domain Recommendation', 'Tackling Noisy Clients in Federated Learning with End-to-end Label Correction', 'DAMe: Personalized Federated Social Event Detection with Dual Aggregation Mechanism', 'ERASE: Error-Resilient Representation Learning on Graphs for Label Noise Tolerance', 'A Power Method to Alleviate Over-smoothing for Recommendation', 'Prompt-Based Spatio-Temporal Graph Transfer Learning', 'Hypergraph Hash Learning for Efficient Trajectory Similarity Computation', 'Causal Probing for Dual Encoders', 'Design Element Aware Poster Layout Generation', 'Large Language Models Enhanced Collaborative Filtering', 'Retrieval Augmented Deep Anomaly Detection for Tabular Data', 'Contrasformer: A Brain Network Contrastive Transformer for Neurodegenerative Condition Identification', 'Veracity Estimation for Entity-Oriented Search with Knowledge Graphs', 'LLaVA-Chef: A Multi-modal Generative Model for Food Recipes', 'Behavior-Aware Hypergraph Convolutional Network for Illegal Parking Prediction with Multi-Source Contextual Information', 'Quantum Cognition-Inspired EEG-based Recommendation via Graph Neural Networks', 'Topological Anonymous Walk Embedding: A New Structural Node Embedding Approach', 'Breaking State-of-the-Art Poisoning Defenses to Federated L ...

# %%
print(len(titles), len(authors))
# Out:
# 348 348

# %%
def graph_mask(title):
    t = title.lower()
    conditions = ['graph neural networks', 'gnns', 'gnn', 'graph', 'graph learning', 'graph embedding', 'network embedding']
    return np.any([c in t for c in conditions])

# %%
with open(f'2024-CIKM.txt', 'w', encoding='utf8') as fw:
    for t, n in zip(titles, authors):
        if graph_mask(t):
            fw.write(f'1. **{t}**\n\n')
            fw.write(f'    *{n}*\n\n')
